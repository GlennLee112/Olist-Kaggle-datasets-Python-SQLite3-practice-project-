# %% [markdown]
# # Importing
#
# Section for importing relevant package and pre-install process;
#
# hidden to avoid cluttering in Notebook

# %%
# Pre-install & main import cluseter - install or import checker 
import pip

# package 
# https://stackoverflow.com/questions/4527554/check-if-module-exists-if-not-install-it
def import_or_install(package):
    try:
        __import__(package)
        print(f"'{package}': import successful")
    except ImportError:
        print(f"'{package}': import error; installing instead")
        pip.main(['install', package])


# import_or_install("pandas")
# import_or_install("scikit-learn")
# import_or_install("tabulate")
# import_or_install("seaborn")
# import_or_install("calplot")

# %%
# Main import cluster
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
import seaborn as sb
import calplot as clp

# %%
from IPython.display import display, Markdown, Latex

# %% [markdown]
# # 0. Load data

# %%
# Load data (csv.)

# Get base path method that works with Jupyter notebook
# https://stackoverflow.com/questions/39125532/file-does-not-exist-in-jupyter-notebook

base_path = os.path.abspath('')
print(base_path)

# read the relevant data from the 'Out' folder
order_seller_review_path = os.path.join(base_path,"Out","order overall.csv")
product_cat_translation_path = os.path.join(base_path,"Out","product cat translation.csv")

date_list = ['order_purchase_timestamp',
             'order_approved_at',
             'order_delivered_carrier_date',
             'order_delivered_customer_date',
             'order_estimated_delivery_date']

# parse_dates = specify which columns to convert to date unit
df_base = pd.read_csv(order_seller_review_path, parse_dates=date_list)

df_product_cat_translation = pd.read_csv(product_cat_translation_path)

# join main table with en product name
df_base = pd.merge(df_base, df_product_cat_translation, on="product_category_name", how="left")

# min and max date of data
min_date = df_base['order_purchase_timestamp'].min().strftime('%Y/%m/%d')
max_date = df_base['order_purchase_timestamp'].max().strftime('%Y/%m/%d')

# df_cat_check = df_base[["product_category_name",'product_category_name_english']].drop_duplicates()
# df_cat_check = df_cat_check.groupby(['product_category_name','product_category_name_english']).size().to_frame()
# display(df_cat_check)

# Create columns variable to be rendered below
columns = df_base.columns.tolist()
# Out:
# G:\Python\SQL-Tk-practice-project

# %% [markdown]
# ## Functions
# Code block containing all functions to be used

# %%
def list_to_stringlist(df_in:list)->str:
    final_string=""
    start_int = 1
    
    for index, item in enumerate(df_in):
        final_string += (f"{start_int}: {item} \n" + 
                         "\n")
        start_int +=1

    return final_string

# format currency function
# https://www.geeksforgeeks.org/how-to-format-numbers-as-currency-strings-in-python/
def format_currency(amount:float|int, currency:str=""):

    format_use = f'{currency+" "}'+'{:,.2f}'
    
    return format_use.format(amount)

# %%
title_with_label = ("# Introduction \n"
                 "\n"
                 "This is the report for sales generated form Olist e-commerce website between **{}** to **{}**").format(min_date, max_date)

# Title markdown display
display(Markdown(f"{title_with_label}"))
# Out:
# # Introduction
#
# This is the report for sales generated form Olist e-commerce website between **2016/09/04** to **2018/10/16**

# %%
# convert columns obtains from above and convert into string list to be used for markdown
column_md_1 = ("## Columnn \n Columns contained within the dataframe of data loaded, displayed below in list as:\n")
column_md_2 = list_to_stringlist(columns)
markdown_space = "\n"


display(Markdown(column_md_1
                + markdown_space
                + column_md_2))
# Out:
# ## Columnn
#  Columns contained within the dataframe of data loaded, displayed below in list as:
#
# 1: order_id
#
# 2: customer_id
#
# 3: order_status
#
# 4: order_purchase_timestamp
#
# 5: order_approved_at
#
# 6: order_delivered_carrier_date
#
# 7: order_delivered_customer_date
#
# 8: order_estimated_delivery_date
#
# 9: seller_id
#
# 10: price
#
# 11: review_score
#
# 12: product_id
#
# 13: product_category_name
#
# 14: product_weight_g
#
# 15: payment_sequential
#
# 16: payment_type
#
# 17: payment_installments
#
# 18: payment_value
#
# 19: product_category_name_english

# %% [markdown]
# # 1. Descriptive analysis
# Display and output sales data in a Descriptive manner:
#
# 1. Sales by product catergory name
# 2. Order Status percentage
# 3. Sales by weight category
# 4. Review score
# 5. Median Price

# %%
# 1. Sales by product category name
df_sales_cat = df_base[["product_category_name_english","price"]]

# All category


# Top 25 and others
# https://stackoverflow.com/questions/67142016/sort-top-n-and-group-others-in-pandas-df
df_sales_cat = df_sales_cat.groupby(["product_category_name_english"]).size().to_frame('sales vol').sort_values(by='sales vol',ascending=False)
df_sales_cat_t10 = df_sales_cat.iloc[:15]
df_sales_cat_others = df_sales_cat.iloc[16:].sum().to_frame('sales vol')

# Rename index from original to 'other'
# https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.rename.html
df_sales_cat_others.rename({'sales vol':'other'}, inplace=True)
df_sales_cat_final = pd.concat([df_sales_cat_t10,df_sales_cat_others])
df_sales_cat_final['sales vol percentage'] = (df_sales_cat_final['sales vol'] / df_sales_cat_final['sales vol'].sum()) * 100
# df_sales_cat_final['sales percentage']

# https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.plot.pie.html

print("1. Sales by product category")
print(df_sales_cat_final)
df_sales_cat_final.plot.pie(y='sales vol', figsize=(25, 25))
# Out:
# 1. Sales by product category
#                        sales vol  sales vol percentage
# bed_bath_table             11988             10.520311
# health_beauty              10032              8.803784
# sports_leisure              9004              7.901642
# furniture_decor             8832              7.750700
# computers_accessories       8150              7.152197
# housewares                  7380              6.476468
# watches_gifts               6213              5.452344
# telephony                   4726              4.147397
# garden_tools                4590              4.028047
# auto                        4400              3.861309
# toys                        4281              3.756878
# cool_stuff                  3999              3.509403
# perfumery                   3589              3.149599
# baby                        3204              2.811735
# electronics                 2846              2.497565
# other                      20717             18.180621
# <Axes: ylabel='sales vol'>

# %%
# 2. Order status percentage

df_order_stat = df_base[["order_status","review_score"]]

df_order_stat_1 = df_order_stat.groupby(["order_status"]).size().to_frame('vol').sort_values(by='vol',ascending=False)
df_order_stat_1['percentage'] = (df_order_stat_1['vol'] / df_order_stat_1['vol'].sum()) * 100

df_order_stat_rev = df_order_stat.groupby(["order_status"]).mean("review_score")
# print(df_order_stat_rev)

df_order_stat_1 = pd.merge(df_order_stat_1, df_order_stat_rev, on="order_status", how="left")

# Reformat float64 to percentage
df_order_stat_1['percentage'] = df_order_stat_1['percentage'].apply(lambda x: f"{x:.2f}%")
df_order_stat_1['review_score'] = df_order_stat_1['review_score'].apply(lambda x: f"{x:.1f}")

# print('The order status break down are as follow \n'
#       '\n'
#      'The table:')
# print(df_order_stat.to_markdown())

markdown_1 = ('The **order status** status are as follow:\n'
              + '\n' 
              + df_order_stat_1.to_markdown())

display(Markdown(markdown_1))
# Out:
# The **order status** status are as follow:
#
# | order_status   |    vol | percentage   |   review_score |
# |:---------------|-------:|:-------------|---------------:|
# | delivered      | 115723 | 97.13%       |            4.1 |
# | shipped        |   1256 | 1.05%        |            2   |
# | canceled       |    749 | 0.63%        |            1.8 |
# | unavailable    |    652 | 0.55%        |            1.5 |
# | invoiced       |    378 | 0.32%        |            1.7 |
# | processing     |    376 | 0.32%        |            1.3 |
# | created        |      5 | 0.00%        |            2.3 |
# | approved       |      3 | 0.00%        |            2   |

# %%
# 3. Sales by weight category
df_weight = df_base.dropna() # Drop na / empty weight data

# Explicit declare of copy to avoid Pandas confusing user trying to slice df
df_weight = df_weight.copy()


# https://stackoverflow.com/questions/58829730/setting-the-values-of-a-pandas-df-column-based-on-ranges-of-values-of-another-df
# solution for truth value error:
# https://stackoverflow.com/questions/36921951/truth-value-of-a-series-is-ambiguous-use-a-empty-a-bool-a-item-a-any-o
# https://stackoverflow.com/questions/71515627/pandas-settingwithcopywarning-on-basic-np-where-statement
conditions = [(df_weight["product_weight_g"] <= 500),
              (df_weight["product_weight_g"] > 500) & (df_weight["product_weight_g"] <= 1000),
              (df_weight["product_weight_g"] > 1000) & (df_weight["product_weight_g"] <= 3000),
              (df_weight["product_weight_g"] > 3000) & (df_weight["product_weight_g"] <= 5000),
              (df_weight["product_weight_g"] > 5000) & (df_weight["product_weight_g"] <= 10000),
              (df_weight["product_weight_g"] > 10000)]

choice = ['<=0.5kg', '>0.5 kg - 1.0 kg', '>1.0KG - 3.0KG', '>3.0KG - 5.0KG', '>5.0KG - 10.0KG','>10.0KG']

df_weight['Weight Cat'] = np.select(conditions, choice, default="Other")

df_weight_final = df_weight.groupby('Weight Cat').size().to_frame('vol')
df_weight_final['percentage'] = (df_weight_final['vol'] / df_weight_final['vol'].sum()) * 100
df_weight_final = df_weight_final.sort_values(by='vol', ascending=False)

# manual sort using list -- data will be sorted after processing, resort data to original order
# https://stackoverflow.com/questions/50012525/how-to-sort-a-pandas-dataframe-by-a-custom-order-on-a-string-index
reindex_list = ['<=0.5kg', '>0.5 kg - 1.0 kg', '>1.0KG - 3.0KG', '>3.0KG - 5.0KG', '>5.0KG - 10.0KG','>10.0KG']
df_weight_final = df_weight_final.reindex(reindex_list)

# print(df_weight_final)

markdown_1 = df_weight_final.to_markdown()
display(Markdown(markdown_1))
df_weight_final_plot = df_weight_final.plot.bar(y='vol')
# Out:
# | Weight Cat       |   vol |   percentage |
# |:-----------------|------:|-------------:|
# | <=0.5kg          | 47245 |     41.7384  |
# | >0.5 kg - 1.0 kg | 20657 |     18.2494  |
# | >1.0KG - 3.0KG   | 26340 |     23.27    |
# | >3.0KG - 5.0KG   |  4872 |      4.30415 |
# | >5.0KG - 10.0KG  |  8723 |      7.70631 |
# | >10.0KG          |  5356 |      4.73174 |

# %%
# 4. Review score
# print(df_base["review_score"].unique()) # debug column only; disable when not required

df_review = df_base[["review_score"]].dropna()

df_review = df_review.groupby(["review_score"]).size().to_frame('vol').sort_values(by='review_score', ascending=False)

df_review['percentage'] = (df_review['vol'] / df_review['vol'].sum()) * 100

display(Markdown(df_review.to_markdown()))
# Out:
# |   review_score |   vol |   percentage |
# |---------------:|------:|-------------:|
# |              5 | 66343 |     56.1539  |
# |              4 | 22319 |     18.8912  |
# |              3 |  9894 |      8.37446 |
# |              2 |  4162 |      3.52279 |
# |              1 | 15427 |     13.0577  |

# %% [markdown]
# # 2. Product analysis

# %% [markdown]
# # 3. Sales analysis
#
# Section for analysis focusing on revenue / sales generated during the period.
#
# ### Brain storming:
# **The following are potential point of analysis regarding sales and revenue:**
# 1. Total Revenue
# 2. Revenue by seller (average/mean, mean, median, quartile)
# 3. Revenue by product category
# 4. Revenue by weight class
# 5. Revenue by dates (Calendar/heatmap & table)

# %%
# 2.1. Total revenue
df_total_revenue = df_base[["price"]].sum()

total_revenue = df_total_revenue.iloc[0]

# format currency function
# https://www.geeksforgeeks.org/how-to-format-numbers-as-currency-strings-in-python/
def format_currency(amount:float|int, currency:str=""):

    format_use = f'{currency+" "}'+'{:,.2f}'
    
    return format_use.format(amount)

total_revenue = format_currency(total_revenue, "BRL")

display(Markdown(f"The total revenue is: **{total_revenue}**"))
# Out:
# The total revenue is: **BRL 14,220,666.42**

# %%
# 2.2. Revenue by seller (average/mean, mean, median, quartile)
df_revenue_seller_base = df_base[["price", "seller_id"]]

df_revenue_seller = df_revenue_seller_base.groupby("seller_id")["price"].sum().to_frame("revenue")
# df_revenue_seller = df_revenue_seller.group_by(["seller_id"])

# 1. Mean
df_revenue_seller_mean = df_revenue_seller.mean().iloc[0]
revenue_seller_mean = format_currency(df_revenue_seller_mean,"BRL")

# 2. Median
df_revenue_seller_median = df_revenue_seller.median().iloc[0]
revenue_seller_median = format_currency(df_revenue_seller_median, "BRL")

# 3. quantile
df_revenue_seller_quar = df_revenue_seller.quantile([.1, .25, .75, .90], method="single", interpolation='nearest')

# 4. Table
df_revenue_count_table = df_revenue_seller_base.groupby("price")["seller_id"].count().to_frame("seller count")
df_revenue_count_table.rename(columns={"price":"revenue"}, inplace=True)
# print(df_revenue_count_table.sort_values(by="seller count", ascending=False))
# df_revenue_count_plot = df_revenue_count_table.plot()


# Markdown
markdown_space = "\n"
markdown_title = "## 3.1 Revenue by seller \n \n ### Summary"
markdown_1 = "1. The the mean revenue of all sellers is: **{}**".format(revenue_seller_mean)
markdown_2 = "2. The the median revenue of all sellers is: **{}**".format(revenue_seller_median)
markdown_3 = ("\n 3. The following is the revenue by quartile breakdown of revenue:" 
              + "\n" 
              + df_revenue_seller_quar.to_markdown())
markdown_4 = "4. Table of seller count distributed by total revenue:"

final_markdown = Markdown(markdown_title 
                          + markdown_space
                          + markdown_1 
                          + markdown_space
                          + markdown_2
                          + markdown_space
                          + markdown_3
                          + markdown_space
                          + markdown_4)

display(final_markdown)

# Histogram / plot
# old method: using Pandas built in '.plot' and '.hist' for graph
# display(df_revenue_count_table.plot())

# new method: use matplotlib directly
fig, ax = plt.subplots(figsize=(5,5))
ax.hist(df_revenue_count_table['seller count'])
ax.set_yscale("log")
# https://stackoverflow.com/questions/21920233/matplotlib-log-scale-tick-label-number-formatting

# df_revenue_count_hist = plt.hist(df_revenue_count_table['seller count'], log=True, bins=50)
# Out:
# ## 3.1 Revenue by seller
#
#  ### Summary
# 1. The the mean revenue of all sellers is: **BRL 4,609.62**
# 2. The the median revenue of all sellers is: **BRL 847.78**
#
#  3. The following is the revenue by quartile breakdown of revenue:
# |      |   revenue |
# |-----:|----------:|
# | 0.1  |     79.99 |
# | 0.25 |    219.8  |
# | 0.75 |   3508.92 |
# | 0.9  |  10045.6  |
# 4. Table of seller count distributed by total revenue:

# %%
# 2.2.1 Revenue by product category (Data)
df_revenue_prodcat_base = df_base[["price", "product_category_name_english"]]

# New 'revenue' and 'sale vol' columns (rename)
df_revenue_prodcat = (df_revenue_prodcat_base.groupby("product_category_name_english").
    agg({'price':'sum','product_category_name_english':'count'}).
    rename(columns={'price':'revenue','product_category_name_english':'sales vol'}).
    sort_values(by="revenue", ascending=False)).reset_index()

# df_revenue_prodcat['revenue per sales'] = df_revenue_prodcat['revenue'] / df_revenue_prodcat['sales vol']
# df_revenue_prodcat
# 3.1 Full list
# Round columns to 2 decimal place
df_revenue_prodcat_full = df_revenue_prodcat.round(2)
df_revenue_prodcat_full['revenue/sales'] = df_revenue_prodcat_full['revenue'] / df_revenue_prodcat_full['sales vol']
df_revenue_prodcat_full['rank'] = df_revenue_prodcat_full['revenue'].rank(method = 'max', ascending=False)
df_revenue_prodcat_full = df_revenue_prodcat_full[['rank','product_category_name_english','revenue','sales vol','revenue/sales']]
df_revenue_prodcat_md = df_revenue_prodcat_full.to_markdown(floatfmt=",.0f")

# Markdown
markdown_1 = "## 3.2 Revenue by product category \n \n Summary of total revenue by product category"

display(Markdown(markdown_1))
display(Markdown(df_revenue_prodcat_md))
# Out:
# ## 3.2 Revenue by product category
#
#  Summary of total revenue by product category
# |    |   rank | product_category_name_english           |   revenue |   sales vol |   revenue/sales |
# |---:|-------:|:----------------------------------------|----------:|------------:|----------------:|
# |  0 |      1 | health_beauty                           | 1,296,350 |       10032 |             129 |
# |  1 |      2 | watches_gifts                           | 1,250,658 |        6213 |             201 |
# |  2 |      3 | bed_bath_table                          | 1,099,575 |       11988 |              92 |
# |  3 |      4 | sports_leisure                          | 1,025,184 |        9004 |             114 |
# |  4 |      5 | computers_accessories                   |   948,078 |        8150 |             116 |
# |  5 |      6 | furniture_decor                         |   771,869 |        8832 |              87 |
# |  6 |      7 | housewares                              |   666,255 |        7380 |              90 |
# |  7 |      8 | cool_stuff                              |   662,013 |        3999 |             166 |
# |  8 |      9 | auto                                    |   615,246 |        4400 |             140 |
# |  9 |     10 | garden_tools                            |   518,156 |        4590 |             113 |
# | 10 |     11 | toys                                    |   498,822 |        4281 |             117 |
# | 11 |     12 | baby                                    |   435,581 |        3204 |             136 |
# | 12 |     13 | perfumery                               |   413,799 |        3589 |             115 |
# | 13 |     14 | telephony                               |   339,695 |        4726 |              72 |
# | 14 |     15 | office_furniture                        |   285,006 |        1788 |             159 |
# | 15 |     16 | computers                               |   242,812 |         220 |           1,104 |
# | 16 |     17 | stationery                              |   235,387 |        2625 |              90 |
# | 17 |     18 | pet_shop                                |   223,360 |        2030 |             110 |
# | 18 |     19 | musical_instruments                     |   210,545 |         719 |             293 |
# | 19 |     20 | small_appliances                        |   200,939 |         705 |             285 |
# | 20 |     21 | consoles_games                          |   166,463 |        1192 |             140 |
# | 21 |     22 | electronics                             |   165,634 |        2846 |              58 |
# | 22 |     23 | fashion_bags_accessories                |   161,343 |        2170 |              74 |
# | 23 |     24 | luggage_accessories                     |   148,350 |        1163 |             128 |
# | 24 |     25 | construction_tools_construction         |   148,277 |         955 |             155 |
# | 25 |     26 | home_appliances_2                       |   123,426 |         270 |             457 |
# | 26 |     27 | home_construction                       |    87,887 |         635 |             138 |
# | 27 |     28 | home_appliances                         |    85,315 |         826 |             103 |
# | 28 |     29 | agro_industry_and_commerce              |    83,639 |         252 |             332 |
# | 29 |     30 | furniture_living_room                   |    72,989 |         532 |             137 |
# | 30 |     31 | home_confort                            |    64,088 |         478 |             134 |
# | 31 |     32 | fixed_telephony                         |    61,741 |         272 |             227 |
# | 32 |     33 | air_conditioning                        |    55,891 |         302 |             185 |
# | 33 |     34 | audio                                   |    52,528 |         381 |             138 |
# | 34 |     35 | kitchen_dining_laundry_garden_furniture |    48,792 |         299 |             163 |
# | 35 |     36 | small_appliances_home_oven_and_coffee   |    48,710 |          78 |             624 |
# | 36 |     37 | books_general_interest                  |    48,133 |         565 |              85 |
# | 37 |     38 | construction_tools_lights               |    42,550 |         314 |             136 |
# | 38 |     39 | construction_tools_safety               |    41,613 |         199 |             209 |
# | 39 |     40 | industry_commerce_and_business          |    40,122 |         272 |             148 |
# | 40 |     41 | food                                    |    30,259 |         526 |              58 |
# | 41 |     42 | market_place                            |    28,574 |         332 |              86 |
# | 42 |     43 | costruction_tools_garden                |    25,065 |         247 |             101 |
# | 43 |     44 | fashion_shoes                           |    24,867 |         278 |              89 |
# | 44 |     45 | art                                     |    24,647 |         219 |             113 |
# | 45 |     46 | drinks                                  |    23,142 |         390 |              59 |
# | 46 |     47 | furniture_bedroom                       |    21,778 |         126 |             173 |
# | 47 |     48 | signaling_and_security                  |    21,035 |         201 |             105 |
# | 48 |     49 | books_technical                         |    19,188 |         272 |              71 |
# | 49 |     50 | food_drink                              |    16,511 |         291 |              57 |
# | 50 |     51 | costruction_tools_tools                 |    16,073 |         105 |             153 |
# | 51 |     52 | fashion_male_clothing                   |    11,577 |         145 |              80 |
# | 52 |     53 | fashion_underwear_beach                 |    10,330 |         144 |              72 |
# | 53 |     54 | christmas_supplies                      |     8,817 |         155 |              57 |
# | 54 |     55 | tablets_printing_image                  |     7,837 |          87 |              90 |
# | 55 |     56 | cine_photo                              |     6,842 |          74 |              92 |
# | 56 |     57 | dvds_blu_ray                            |     6,509 |          71 |              92 |
# | 57 |     58 | music                                   |     6,335 |          40 |             158 |
# | 58 |     59 | furniture_mattress_and_upholstery       |     4,836 |          41 |             118 |
# | 59 |     60 | party_supplies                          |     4,755 |          46 |             103 |
# | 60 |     61 | books_imported                          |     4,622 |          62 |              75 |
# | 61 |     62 | fashio_female_clothing                  |     2,884 |          50 |              58 |
# | 62 |     63 | la_cuisine                              |     2,293 |          16 |             143 |
# | 63 |     64 | fashion_sport                           |     2,154 |          31 |              69 |
# | 64 |     65 | arts_and_craftmanship                   |     1,794 |          24 |              75 |
# | 65 |     66 | diapers_and_hygiene                     |     1,568 |          39 |              40 |
# | 66 |     67 | flowers                                 |     1,062 |          33 |              32 |
# | 67 |     68 | home_comfort_2                          |       773 |          31 |              25 |
# | 68 |     69 | cds_dvds_musicals                       |       730 |          14 |              52 |
# | 69 |     70 | fashion_childrens_clothes               |       560 |           8 |              70 |
# | 70 |     71 | security_and_services                   |       283 |           2 |             142 |

# %%
# 3. Revenue by product category (Graph / visualization)

# Revenue (rev) & revenue per sales (rps)
# 3.3 Top 30 and total
# df_revenue_prodcat_rev_all = df_revenue_prodcat_full

# # Create a sum of items from 30th onward for 'Total' row and merge
# # https://stackoverflow.com/questions/41286569/get-total-of-pandas-column
# # df_revenue_prodcat_rev_25 = df_revenue_prodcat_rev_all.iloc[:30] # select first 30 entry
# # df_revenue_prodcat_rev_other = df_revenue_prodcat_rev_all.iloc[30:].sum(numeric_only=True) # sum into 'total'
# # df_revenue_prodcat_rev_final = df_revenue_prodcat_rev_25.copy() # Create a copy to prevent warning
# # df_revenue_prodcat_rev_final.loc['others'] = df_revenue_prodcat_rev_other # set 'other' row
# df_revenue_prodcat_rev_all['revenue/sales'] = df_revenue_prodcat_rev_all['revenue'] / df_revenue_prodcat_rev_all['sales vol']

# df_revenue_prodcat_rev_final # Debugging - display table; disable if not needed
# Option 1 - matplotlib
# Multi axis plot utilizing matplotlib
# https://stackoverflow.com/questions/11640243/plot-multiple-y-axes
fig, ax = plt.subplots()
ax3 = ax.twinx()
rspine = ax3.spines['right']
rspine.set_position(('axes', 1.15))
ax3.set_frame_on(True)
ax3.patch.set_visible(False)
fig.subplots_adjust(right=0.7)

x_axis = ax.axes.get_xaxis()
x_axis.set_visible(False)

df_revenue_prodcat_full['revenue'].plot(ax=ax, style='b-')
df_revenue_prodcat_full['sales vol'].plot(ax=ax, style='r-', secondary_y=True)
df_revenue_prodcat_full['revenue/sales'].plot(ax=ax3, style='g-')

display(fig)

# %% [markdown]
# **Note: Red line is sales volume, Blue is the total revenue, & green is the price per sales/unit**
#
# From graph and table of Revenue by product category above, it can be observed that majority of top product category by revenue are low margin high volume items, with high unit sold for on average lower than BRL 200 per sales.
#
# Olist market are currently targeting

# %%
# 3.3 revenue by weight

df_weight_revenue_base = df_weight.copy()

# Group by weight cat
df_weight_revenue = df_weight_revenue_base.groupby("Weight Cat")['price'].sum().to_frame('total revenue')
df_weight_revenue['total revenue %'] = (df_weight_revenue['total revenue'] / df_weight_revenue['total revenue'].sum()) * 100

# Group by weight cat (sales vol) -- to be joined with the first table
df_weight_sales_vol = df_weight_revenue_base.groupby("Weight Cat").size().to_frame('sales vol')

# join df_weight_revenue with df_weight_sales_vol
df_weight_revenue = pd.merge(df_weight_revenue, df_weight_sales_vol, on="Weight Cat", how="left")

# Revenue per sales
# manual sort using list -- data will be sorted after processing, resort data to original order
# https://stackoverflow.com/questions/50012525/how-to-sort-a-pandas-dataframe-by-a-custom-order-on-a-string-index
df_weight_revenue['revenue / sales'] = df_weight_revenue['total revenue'] / df_weight_revenue['sales vol']
reindex_list = ['<=0.5kg', '>0.5 kg - 1.0 kg', '>1.0KG - 3.0KG', '>3.0KG - 5.0KG', '>5.0KG - 10.0KG','>10.0KG']
df_weight_revenue = df_weight_revenue.reindex(reindex_list)

markdown_title = "## 3.3 Revenue by weight\n \nThe following is the data and graph chart of revenue by weight:"
df_weight_revenue_md = Markdown(df_weight_revenue.to_markdown(floatfmt=",.0f"))

display(Markdown(markdown_title))
display(df_weight_revenue_md)

df_weight_revenue_plot = df_weight_revenue.plot.bar(y='total revenue')
# Out:
# ## 3.3 Revenue by weight
#
# The following is the data and graph chart of revenue by weight:
# | Weight Cat       |   total revenue |   total revenue % |   sales vol |   revenue / sales |
# |:-----------------|----------------:|------------------:|------------:|------------------:|
# | <=0.5kg          |       3,628,283 |                27 |      47,245 |                77 |
# | >0.5 kg - 1.0 kg |       2,304,840 |                17 |      20,657 |               112 |
# | >1.0KG - 3.0KG   |       3,348,108 |                25 |      26,340 |               127 |
# | >3.0KG - 5.0KG   |         901,892 |                 7 |       4,872 |               185 |
# | >5.0KG - 10.0KG  |       1,566,151 |                12 |       8,723 |               180 |
# | >10.0KG          |       1,765,216 |                13 |       5,356 |               330 |

# %% [markdown]
# ## 3.4 Sales / purchase by day and time
#
# A visualisation of sales/purchase made by day and time; visualised using heatmap

# %%
# 3.4 Revenue by weekdays and time of days
# Subdivide date into
df_time_day = df_base[['order_purchase_timestamp']].copy()
# df_time_day # for debugging, disable when not required

df_time_day['weekday'] = df_time_day['order_purchase_timestamp'].dt.weekday + 1 #offset by one day, since weekday is starting from 0
df_time_day['hours'] = df_time_day['order_purchase_timestamp'].dt.hour
# df_time_day = df_time_day[['weekday','hours']]
# df_time_day.set_index(['weekday','hours'],append=True)

df_time_day_piv = df_time_day.pivot_table(index="weekday", columns = "hours", aggfunc="count")
df_time_day_piv

# Heatmap
# https://seaborn.pydata.org/generated/seaborn.heatmap.html
plt.figure(figsize=(14, 7)) # 
sb.heatmap(df_time_day_piv, cmap="coolwarm", annot=True,annot_kws={'size':8}, fmt=".0f") # adjust annot, annot_kws(keywords), format
plt.title('Purchase volume - Day and Time') # retitle graph
plt.show()

# %% [markdown]
# - From the heatmap, it can be observed that sales/purchase peaks are during weekday between **10AM to 4PM**.
# - During weekdays, sales activity remain persistent throughout Monday to Thursday, with activity remaining high from **9AM to 10PM**.
# - During weekend, the sales are the lowest during Saturday with sales lower on the usual sales period compared to other days; during Sunday, users are likely to purchase between **6PM to 10PM**.
# - Using the information above, Olist can time their marketing Call to Action effort according to customer activity.

# %% [markdown]
# ## 3.5 Sales by date
# The total sales of olist visualized in calendary format
#
# Module used: **calplot**

# %%
# Create a copy from base dataframe to be used for calplot purpose
df_calplot = df_base.copy()

# 
df_calplot = df_calplot[["order_delivered_customer_date","price"]]
# df_calplot["order_purchase_timestamp"] = df_calplot["order_purchase_timestamp"].dt.date
# df_calplot= df_calplot[df_calplot['order_purchase_timestamp']!='2017-11-24']
df_calplot = df_calplot.groupby(["order_delivered_customer_date"])['price'].sum().dropna()
print(df_calplot.dtypes)
print(df_calplot)
# df_calplot = df_calplot[["order_purchase_timestamp"]] != '2017-11-24'


calplot_final = clp.calplot(df_calplot)
# Out:
# float64
# order_delivered_customer_date
# 2016-10-11 13:46:32     47.80
# 2016-10-11 14:46:49     93.90
# 2016-10-13 03:10:34     19.99
# 2016-10-13 07:45:48    149.99
# 2016-10-13 15:44:27    294.90
#                         ...
# 2018-09-25 00:47:25     49.90
# 2018-09-27 02:24:33    209.99
# 2018-10-02 00:18:50     70.00
# 2018-10-11 16:41:14    179.00
# 2018-10-17 13:22:46     26.40
# Name: price, Length: 95664, dtype: float64

# %% [markdown]
# **Note: due to anomoly in purchase timestamp data, order delivery will be used in liue of purchase timestamp**
#
# The above calendar plot highlighted the majority of the sales are generated during 2018, and aside from a few sporadic exception, majority of sales are completed during weekdays

# %% [markdown]
# # 4. Exploratory analysis
#
# Exploratory analysis between variable available in the sales data, to present any possible correlation and predictive model that can be derived; including but not limited to: **Correlation, Clustering, Regression**
#
# ## Brainstorming
# 1. Clustter
# 2. Correlation matrix (numeric columns only)
#
#
# ##### Reference materials on what analysis are performed:
# https://www.sfu.ca/~mjbrydon/tutorials/BAinPy/08_correlation.html
#
# https://www.kaggle.com/code/terencicp/sql-challenge-e-commerce-data-analysis#Linear-regression

# %%
# Back up - Delivery Time Taken and Delivery Time Dif

# Pre-process; convert relevant column to datetime
# col_to_convert = ["order_delivered_customer_date", "order_purchase_timestamp", "order_approved_at",
#                   "order_delivered_carrier_date", "order_estimated_delivery_date"]

# df_cor_reg = p_pd.convert_to_datetime(df_base, col_to_convert)
df_cor_reg = df_base
# new column
# Delivery Time Taken - time between order is place and order is delivered
df_cor_reg["Delivery Time Taken"] = df_cor_reg["order_delivered_customer_date"] - df_cor_reg["order_purchase_timestamp"]
# delivery time dif - difference between estimated and actual delivery date
df_cor_reg["Delivery Time Dif"] = df_cor_reg["order_delivered_customer_date"] - df_cor_reg["order_estimated_delivery_date"]

# Drop NaN
df_cor_reg.dropna(subset=["review_score","Delivery Time Taken"], inplace=True)

# Convert to day 
df_cor_reg["Delivery Time Dif"] = df_cor_reg["Delivery Time Dif"].dt.days
df_cor_reg["Delivery Time Taken"] = df_cor_reg["Delivery Time Taken"].dt.days

# df_cor_reg.reset_index(inplace=True)

# review_unique = df_cor_reg["review_score"].unique()
# print(review_unique)
# print(df_cor_reg)

# %% [markdown]
# ## Correlation
#
# Correlation matrix for customer

# %%
# Correlation
# heatmap: https://matplotlib.org/stable/gallery/images_contours_and_fields/image_annotated_heatmap.html
df_cor_reg_2 = df_cor_reg[['price', 'review_score', 'product_weight_g', 'Delivery Time Taken', 'Delivery Time Dif', 'payment_installments','payment_value']]

corr_mat = df_cor_reg_2.corr(numeric_only=True)
corr_mat = round(corr_mat,2) # round to 2 decimal place
# print(round(corr_mat,2))

ax_heatmap = sb.heatmap(corr_mat, cmap="Blues", annot=True)
# # https://seaborn.pydata.org/generated/seaborn.FacetGrid.set_xticklabels.html
# label_list = [ in ax_heatmap.get_xticks()]

# Extract the text content of the labels
xticklabels_objects = ax_heatmap.get_xticklabels()

xticklabels_text = [label.get_text() for label in xticklabels_objects] # list comprehension to get text from the xticklabel objects
print(xticklabels_text)

ax_heatmap.set_xticklabels(xticklabels_text, rotation=45, ha='right')
# Out:
# ['price', 'review_score', 'product_weight_g', 'Delivery Time Taken', 'Delivery Time Dif', 'payment_installments', 'payment_value']
# [Text(0.5, 0, 'price'),
#  Text(1.5, 0, 'review_score'),
#  Text(2.5, 0, 'product_weight_g'),
#  Text(3.5, 0, 'Delivery Time Taken'),
#  Text(4.5, 0, 'Delivery Time Dif'),
#  Text(5.5, 0, 'payment_installments'),
#  Text(6.5, 0, 'payment_value')]

# %% [markdown]
# From the correlation matrix above, the following notable observation can be made:
# 1. **Product weight** have a **slight positive correlation (0.34)** with **price**
#
# With olist having made most of the revenue from low price/margin items, it is can be said that most items sold are small to medium size in dimension. **Olist should adjust their marketing and operation accordingly to accommodate for low margin, high volume items**.
#
# 2. **Delivery Time Taken** and **Delay between actual and estimated delivery time** have a slight negative correlation (**-0.3 & -0.23,** respectively) with **review_score**
#
# The longer the delivery time and the greater the difference between estimated delivery time and actual delivery time, the lower the customer review score; seller and olist should emphasize on delivery timeliness and estimated delivery date accurarcy to improve overall customer satisfaction.
#
# 3. Implication of price & weight having little to no review score.
#
# From the correlation matrix, it can be noted that price and weight have no or negligible impact on review score, one implication of this is that customer have similar if not the same amount of quality expectation across all product ranges by price and weight, despite the majority of revenue is generated from lighter weight product,

# %% [markdown]
# # 5. Forecasting
# Using ML methods and modules (such as sklearn) to create a forecasting of sales by product category
#
# References:
# https://www.kaggle.com/code/ryanholbrook/linear-regression-with-time-series

# %%
# # Visualise 'review_score' and 'delivery_time_take"
# import matplotlib.pyplot as plt
# import seaborn as sns

# plt.subplot(1,2,2)
# sns.scatterplot(x=x, y=y, alpha=0.5)
# plt.plot([min(y), max(y)], [min(x), max(x)], color='red', linestyle='--')
# plt.title("Regression Fit: Actual vs Predicted")
# plt.xlabel("Actual Prices (in $100,000s)")
# plt.ylabel("Predicted Prices (in $100,000s)")

# plt.show()

# %% [markdown]
# # Backup
# Containing code blocks that is not in used; back up on the end of notebook just in case / for reference.

# %%
# # Understanding Linear Regression (Sklearn)
# # https://www.datacamp.com/tutorial/sklearn-linear-regression

# # Linear regression testing for review score and delivery time taken

# # Import train_test_split.
# from sklearn.model_selection import train_test_split

# # Split the dataset into training (80%) and testing (20%) sets.
# X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
# # Import LinearRegression.
# from sklearn.linear_model import LinearRegression


# # Instantiate linear regression model.
# model = LinearRegression()

# %%
# model.fit(X_test, y_test)

# %%
# from sklearn.metrics import mean_squared_error, r2_score

# y_pred = model.predict(X_test)

# # Calculate and print R^2 score.
# r2 = r2_score(y_test, y_pred)
# print(f"R-squared: {r2:.4f}")

# %%
# # Cluster
# df_cor_reg_plot = df_cor_reg

# # Convert to days
# df_cor_reg_plot["Delivery Time Dif"] = df_cor_reg_plot["Delivery Time Dif"].dt.days
# df_cor_reg_plot["Delivery Time Taken"] = df_cor_reg_plot["Delivery Time Taken"].dt.days

# df_cor_reg_plot.plot.scatter(x="review_score",
#                              y="Delivery Time Dif")

# # df_cor_reg_plot["Delivery Time Taken"] = df_cor_reg_plot["Delivery Time Taken"].dt.days

# df_cor_reg_plot.plot.scatter(x="review_score",
#                              y="Delivery Time Taken")
